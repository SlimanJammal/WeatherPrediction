# %% [markdown]
# # Importing Data and Visualization

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os


df = pd.read_csv('drive/MyDrive/Colab Notebooks/london_weather.csv')
df
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0      19790101          2.0       7.0              52.0       2.3       -4.1
# 1      19790102          6.0       1.7              27.0       1.6       -2.6
# 2      19790103          5.0       0.0              13.0       1.3       -2.8
# 3      19790104          8.0       0.0              13.0      -0.3       -2.6
# 4      19790105          6.0       2.0              29.0       5.6       -0.8
# ...         ...          ...       ...               ...       ...        ...
# 15336  20201227          1.0       0.9              32.0       7.5        7.5
# 15337  20201228          7.0       3.7              38.0       3.6        1.1
# 15338  20201229          7.0       0.0              21.0       4.1        2.6
# 15339  20201230          6.0       0.4              22.0       5.6        2.7
# 15340  20201231          7.0       1.3              34.0       1.5       -0.8
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15341 entries, 0 to 15340
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              15341 non-null  int64
#  1   cloud_cover       15322 non-null  float64
#  2   sunshine          15341 non-null  float64
#  3   global_radiation  15322 non-null  float64
#  4   max_temp          15335 non-null  float64
#  5   mean_temp         15305 non-null  float64
#  6   min_temp          15339 non-null  float64
#  7   precipitation     15335 non-null  float64
#  8   pressure          15337 non-null  float64
#  9   snow_depth        13900 non-null  float64
# dtypes: float64(9), int64(1)
# memory usage: 1.2 MB

# %%
df.isnull().sum()
# Out:
# date                   0
# cloud_cover           19
# sunshine               0
# global_radiation      19
# max_temp               6
# mean_temp             36
# min_temp               2
# precipitation          6
# pressure               4
# snow_depth          1441
# dtype: int64

# %%
# replacing null values with the mean
mean_cloud_cover = df['cloud_cover'].mean()
df['cloud_cover'].fillna(mean_cloud_cover, inplace=True)

mean_global_radiation = df['global_radiation'].mean()
df['global_radiation'].fillna(mean_global_radiation, inplace=True)

# Forward fill and backward fill for 'max_temp' column
df['max_temp'] = df['max_temp'].ffill().bfill()

# Interpolate missing values using linear method for 'mean_temp' column
df['mean_temp'] = df['mean_temp'].interpolate(method='linear')

# Fill missing values with median for 'min_temp' column
df['min_temp'] = df['min_temp'].fillna(df['min_temp'].median())

# Fill missing values with 0 for 'precipitation' column
df['precipitation'] = df['precipitation'].fillna(0)

# Forward fill and backward fill for 'pressure' column
df['pressure'] = df['pressure'].ffill().bfill()

# Fill missing values with 0 for 'snow_depth' column
df['snow_depth'] = df['snow_depth'].fillna(0)


df.head()
# Out:
#        date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0  19790101          2.0       7.0              52.0       2.3       -4.1
# 1  19790102          6.0       1.7              27.0       1.6       -2.6
# 2  19790103          5.0       0.0              13.0       1.3       -2.8
# 3  19790104          8.0       0.0              13.0      -0.3       -2.6
# 4  19790105          6.0       2.0              29.0       5.6       -0.8
#
#    min_temp  precipitation  pressure  snow_depth
# 0      -7.5            0.4  101900.0         9.0
# 1      -7.5            0.0  102530.0         8.0
# 2      -7.2            0.0  102050.0         4.0
# 3      -6.5            0.0  100840.0         2.0
# 4      -1.4            0.0  102250.0         1.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
df.isnull().sum()
# Out:
# date                0
# cloud_cover         0
# sunshine            0
# global_radiation    0
# max_temp            0
# mean_temp           0
# min_temp            0
# precipitation       0
# pressure            0
# snow_depth          0
# dtype: int64

# %%
#converting date to dfdate
df.index = pd.to_datetime(df['date'], format='%Y%m%d')
df[:20]
df.drop(columns='date', inplace=True)

# %%
pressure = df['pressure'][0:730]
plt.plot(pressure)
plt.xlabel('Time Step')  # Set x-axis title
plt.ylabel('Mpressure')  # Set y-axis title
plt.title('pressure Over Time (First 730 days)')
# Out:
# Text(0.5, 1.0, 'pressure Over Time (First 730 days)')

# %%
#plotting (simple plot) the features that we are planing on predicting
mean_temp = df['mean_temp'][0:1095]
pressure = df['pressure'][0:1095]
min_temp = df['min_temp'][0:1095]

plt.figure(figsize=(18,5))
plt.subplot(131)
plt.plot(mean_temp)
plt.xlabel('Time Step')  # Set x-axis title
plt.ylabel('Mean Temperature')  # Set y-axis title
plt.title('Mean Temperature Over Time (First 1095 days)')


plt.subplot(132)
plt.plot(pressure)
plt.xlabel('Time Step')  # Set x-axis title
plt.ylabel('pressure')  # Set y-axis title
plt.title('pressure Over Time (First 1095 days)')


plt.subplot(133)
plt.plot(min_temp)
plt.xlabel('Time Step')  # Set x-axis title
plt.ylabel('min_temp')  # Set y-axis title
plt.title('min_temp Over Time (First 1095 days)')
# Out:
# Text(0.5, 1.0, 'min_temp Over Time (First 1095 days)')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
plt.subplot(331)
plt.hist(df['mean_temp'], bins=80)
plt.xlabel(' mean temp values')
plt.ylabel('Frequency')
plt.title('Histogram of mean_temp Values')
# plt.show()

plt.subplot(332)
plt.hist(df['max_temp'], bins=80)
plt.xlabel('max_temp values')
plt.ylabel('Frequency')
plt.title('Histogram of max_temp Values')
# plt.show()

plt.subplot(333)
plt.hist(df['min_temp'], bins=80)
plt.xlabel('min_temp values')
plt.ylabel('Frequency')
plt.title('Histogram of min_temp Values')
# plt.show()

plt.subplot(334)
plt.hist(df['cloud_cover'], bins=80)
plt.xlabel(' cloud_cover values')
plt.ylabel('Frequency')
plt.title('Histogram of cloud_cover Values')
# plt.show()

plt.subplot(335)
plt.hist(df['sunshine'], bins=80)
plt.xlabel('sunshine values')
plt.ylabel('Frequency')
plt.title('Histogram of sunshine Values')
# plt.show()

plt.subplot(336)
plt.hist(df['snow_depth'], bins=80)
plt.xlabel('snow_depth values')
plt.ylabel('Frequency')
plt.title('Histogram of snow_depth Values')
# plt.show()

plt.subplot(337)
plt.hist(df['pressure'], bins=80)
plt.xlabel('pressure values')
plt.ylabel('Frequency')
plt.title('Histogram of pressure Values')
# plt.show()

plt.subplot(338)
plt.hist(df['global_radiation'], bins=80)
plt.xlabel('global_radiation values')
plt.ylabel('Frequency')
plt.title('Histogram of global_radiation Values')
plt.show()

# %%
max_temp = df['max_temp']
max_temp.plot()
# Out:
# <Axes: xlabel='date'>

# %%
min_temp = df['min_temp']
min_temp.plot()
# Out:
# <Axes: xlabel='date'>

# %%
# we can see that the data is cyclic, thus we define two new columns sin_year and sin_day a common method for dealing with such data
day_of_year = df.index.dayofyear
df['day_sin'] = np.sin(2 * np.pi * day_of_year / 365)
df['day_cos'] = np.cos(2 * np.pi * day_of_year / 365)


df.head()
# Out:
#             cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# date
# 1979-01-01          2.0       7.0              52.0       2.3       -4.1
# 1979-01-02          6.0       1.7              27.0       1.6       -2.6
# 1979-01-03          5.0       0.0              13.0       1.3       -2.8
# 1979-01-04          8.0       0.0              13.0      -0.3       -2.6
# 1979-01-05          6.0       2.0              29.0       5.6       -0.8
#
#             min_temp  precipitation  pressure  snow_depth   day_sin   day_cos
# date
# 1979-01-01      -7.5            0.4  101900.0         9.0  0.017213  0.999852
# 1979-01-02      -7.5            0.0  102530.0         8.0  0.034422  0.999407
# 1979-01-03      -7.2            0.0  102050.0         4.0  0.051620  0.998667
# 1979-01-04      -6.5            0.0  100840.0         2.0  0.068802  0.997630
# 1979-01-05      -1.4            0.0  102250.0         1.0  0.085965  0.996298

# %%
temp = df['day_sin'][0:730]
temp.plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# # Data preperation

# %%
temp_c = df['day_cos']
temp_c.plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# **Trying a different Scaling approach**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler

def scaler_fit_transform(data, scaler):
    data_flattened = data.reshape(-1, data.shape[-1])
    scaler.fit(data_flattened)

    return scaler.transform(data_flattened).reshape(data.shape)

# %%
# we prepare the data into input and labels and return them as np arrays
def prepare_data(df, kernel=50):
    np_df = df.to_numpy()
    scaler = RobustScaler()
    np_df = scaler_fit_transform(np_df, scaler)
    input_data = [np_df[i:i+kernel] for i in range(len(np_df) - kernel)]
    # 3 is max_temp, 4 is mean_temp and 5 is min_temp
    labels = [[np_df[i+kernel][3], np_df[i+kernel][4], np_df[i+kernel][5]] for i in range(len(np_df) - kernel)]
    return np.array(input_data), np.array(labels), scaler

# %%
# converting the data from df to input and labels then splitting the data to train, validation and test sets.
x, y, scaler = prepare_data(df)
len_train = int(0.8 * len(x))
len_val = int(0.1 * len(x))
x_train, y_train = x[:len_train], y[:len_train]
x_val, y_val = x[len_train:len_train + len_val], y[len_train:len_train + len_val]
x_test, y_test = x[len_train + len_val:], y[len_train + len_val:]

print(x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape)
# Out:
# (12232, 50, 11) (12232, 3) (1529, 50, 11) (1529, 3) (1530, 50, 11) (1530, 3)

# %%
print(x_train)
x_train.shape
# Out:
# [[[-1.33333333  0.52238806 -0.29655172 ...  9.          0.01219796
#     0.70548515]
#   [ 0.         -0.26865672 -0.46896552 ...  8.          0.0243923
#     0.7051702 ]
#   [-0.33333333 -0.52238806 -0.56551724 ...  4.          0.03657941
#     0.7046454 ]
#   ...
#   [ 0.66666667 -0.52238806 -0.47586207 ...  0.          0.52114095
#     0.47713515]
#   [ 0.66666667 -0.52238806 -0.47586207 ...  0.          0.52932925
#     0.46809334]
#   [ 0.66666667 -0.52238806 -0.46896552 ...  0.          0.5373607
#     0.45891192]]
#
#  [[ 0.         -0.26865672 -0.46896552 ...  8.          0.0243923
#     0.7051702 ]
#   [-0.33333333 -0.52238806 -0.56551724 ...  4.          0.03657941
#     0.7046454 ]
#   [ 0.66666667 -0.52238806 -0.56551724 ...  2.          0.04875569
#     0.70391088]
#   ...
#   [ 0.66666667 -0.52238806 -0.47586207 ...  0.          0.52932925
#     0.46809334]
#   [ 0.66666667 -0.52238806 -0.46896552 ...  0.          0.5373607
#     0.45891192]
# ...

# %% [markdown]
# # Model Definition

# %%
import torch
import torch.nn as nn

class GRU_(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers=2):
        super(GRU_, self).__init__()
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)


    def forward(self, x):
        out, _ = self.gru(x)
        return out[:, -1, :]

class Main_Model(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(Main_Model, self).__init__()
        self.gru = GRU_(input_size, hidden_size)
        self.fc1 = nn.Linear(hidden_size, 64)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(64, output_size)

    def forward(self, x):
        out = self.gru(x)
        out = self.fc1(out)
        out = self.relu(out)
        out = self.fc2(out)
        return out


input_dim = 11
sequence_length = 50
hidden_size = 32
output_dim = 3


model = Main_Model(input_dim, hidden_size, output_dim)
print(model)
# Out:
# Main_Model(
#   (gru): GRU_(
#     (gru): GRU(11, 32, num_layers=2, batch_first=True)
#   )
#   (fc1): Linear(in_features=32, out_features=64, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=64, out_features=3, bias=True)
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(count_parameters(model))
# Out:
# 12963

# %% [markdown]
# # Model Training

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import os
from torch.utils.data import TensorDataset, DataLoader


x_train_tensor = torch.tensor(x_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
x_val_tensor = torch.tensor(x_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32)

train_dataset = TensorDataset(x_train_tensor, y_train_tensor)
val_dataset = TensorDataset(x_val_tensor, y_val_tensor)

batch_size = 32

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

num_epochs = 10
for epoch in range(num_epochs):
    model.train()
    total_train_loss = 0.0
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_train_loss += loss.item()

    # Validation loop
    model.eval()
    with torch.no_grad():
        total_val_loss = 0.0
        for inputs, labels in val_loader:
            outputs = model(inputs)
            val_loss = criterion(outputs, labels)
            total_val_loss += val_loss.item()
        avg_val_loss = total_val_loss / len(val_loader)

    avg_train_loss = total_train_loss / len(train_loader)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_train_loss:.4f}, Avg. Val. Loss: {avg_val_loss:.4f}')
# Out:
# Epoch [1/10], Train Loss: 0.1968, Avg. Val. Loss: 0.0900
# Epoch [2/10], Train Loss: 0.0888, Avg. Val. Loss: 0.0742
# Epoch [3/10], Train Loss: 0.0714, Avg. Val. Loss: 0.0623
# Epoch [4/10], Train Loss: 0.0581, Avg. Val. Loss: 0.0532
# Epoch [5/10], Train Loss: 0.0508, Avg. Val. Loss: 0.0495
# Epoch [6/10], Train Loss: 0.0475, Avg. Val. Loss: 0.0470
# Epoch [7/10], Train Loss: 0.0459, Avg. Val. Loss: 0.0459
# Epoch [8/10], Train Loss: 0.0448, Avg. Val. Loss: 0.0464
# Epoch [9/10], Train Loss: 0.0439, Avg. Val. Loss: 0.0438
# Epoch [10/10], Train Loss: 0.0433, Avg. Val. Loss: 0.0438

# %% [markdown]
# # Model Testing

# %%
#testing the model
x_test_tensor = torch.tensor(x_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32)


test_dataset = TensorDataset(x_test_tensor, y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=batch_size)


model.eval()
with torch.no_grad():
    total_test_loss = 0.0
    for inputs, labels in test_loader:
        outputs = model(inputs)
        test_loss = criterion(outputs, labels)
        total_test_loss += test_loss.item()
    avg_test_loss = total_test_loss / len(test_loader)

print(f'Avg. Test Loss: {avg_test_loss:.4f}')


model.eval()
correct_predictions = 0
total_samples = 0
predictions = []
with torch.no_grad():
    for inputs, labels in test_loader:
        outputs = model(inputs)
        predictions.append(outputs.numpy())
        total_samples += labels.size(0)
        correct_predictions += ((outputs - labels).abs() < 0.5).sum().item()
# Concatenate predictions into a single NumPy array

accuracy = correct_predictions / total_samples
# print(f'Accuracy: {accuracy:.4f}')
predictions_np = np.concatenate(predictions, axis=0)
print(predictions_np)
# Out:
# Avg. Test Loss: 0.0530
# [[-0.2145501  -0.19597384 -0.14953521]
#  [-0.10815091 -0.02342042  0.05931997]
#  [-0.00159826  0.12848732  0.2078521 ]
#  ...
#  [-0.96921223 -1.1000553  -1.0110445 ]
#  [-0.96165925 -1.0929171  -1.0048456 ]
#  [-0.92733496 -1.0385312  -0.97976714]]

# %%
def denormalize_predictions(scaled_data, data):
    median = np.median(data)
    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    iqr = q3 - q1
    orig_data = scaled_data * iqr + median
    return orig_data



max_temp_pred = denormalize_predictions(predictions_np[:, 0], df['max_temp'][-1530:])

mean_temp_pred = denormalize_predictions(predictions_np[:, 1], df['mean_temp'][-1530:])

min_temp_pred = denormalize_predictions(predictions_np[:, 2], df['min_temp'][-1530:])

df_final = pd.DataFrame(data={'max_temp_pred': max_temp_pred,'max_temp_orig': df['max_temp'][-1530:],
                              'mean_temp_pred': mean_temp_pred, 'mean_temp_orig': df['mean_temp'][-1530:],
                              'min_temp_pred': min_temp_pred, 'min_temp_orig': df['min_temp'][-1530:]})

df_final.head()
# Out:
#             max_temp_pred  max_temp_orig  mean_temp_pred  mean_temp_orig  \
# date
# 2016-10-24      13.204314           14.1        9.916637            11.4
# 2016-10-25      14.342785           16.5       11.486874            11.8
# 2016-10-26      15.482899           16.5       12.869234            13.0
# 2016-10-27      15.551465           17.2       12.984793            12.2
# 2016-10-28      15.842978           15.3       13.206897            13.5
#
#             min_temp_pred  min_temp_orig
# date
# 2016-10-24       7.048579            9.5
# 2016-10-25       8.656763            9.6
# 2016-10-26       9.800461            9.4
# 2016-10-27       9.812423            7.8
# 2016-10-28       9.809502            9.8

# %%
print(max_temp_pred.shape)
print(mean_temp_pred.shape)
print(min_temp_pred.shape)
print(y_test.shape)
# Out:
# (1530,)
# (1530,)
# (1530,)
# (1530, 3)

# %% [markdown]
# # Prediction results Plotting

# %%
colors = ['#6a0dad', '#4caf50']

plt.figure(figsize=(12, 6))
plt.plot(df_final['max_temp_orig'][0:600], color=colors[0], label='Original Max Temp')
plt.plot(df_final['max_temp_pred'][0:600], color=colors[1], label='Predicted Max Temp')

plt.title('Max Temperature Prediction', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Temperature', fontsize=14)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.legend(fontsize=12)

plt.grid(True, linestyle='--', alpha=0.7)

plt.gca().set_facecolor('#f0f0f0')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.show()

# %%
colors = ['#6a0dad', '#4caf50']

plt.figure(figsize=(12, 6))
plt.plot(df_final['mean_temp_orig'][0:600], color=colors[0], label='Original Mean Temp')
plt.plot(df_final['mean_temp_pred'][0:600], color=colors[1], label='Predicted Mean Temp')

plt.title('Mean Temperature Prediction', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Temperature', fontsize=14)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.legend(fontsize=12)

plt.grid(True, linestyle='--', alpha=0.7)

plt.gca().set_facecolor('#f0f0f0')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.show()

# %%
colors = ['#6a0dad', '#4caf50']

plt.figure(figsize=(12, 6))
plt.plot(df_final['min_temp_orig'][0:600], color=colors[0], label='Original Min Temp')
plt.plot(df_final['min_temp_pred'][0:600], color=colors[1], label='Predicted Min Temp')

plt.title('Min Temperature Prediction', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Temperature', fontsize=14)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.legend(fontsize=12)

plt.grid(True, linestyle='--', alpha=0.7)

plt.gca().set_facecolor('#f0f0f0')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.show()
